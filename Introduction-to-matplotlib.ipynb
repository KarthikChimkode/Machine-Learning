# %% [markdown]
# # Introduction to Matlpotlib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot()
# Out:
# []

# %%
plt.plot();

# %%
plt.plot()
plt.show()

# %%
plt.plot([1,2,3,4]);

# %%
x =[1,2,3,4]
y =[11,22,33,44]
plt.plot(x,y);

# %%
# method 1
fig = plt.figure() #creates a figure
ax = fig.add_subplot() #adds some axes
plt.show()

# %%
#2nd method
fig = plt.figure() #creates a figure
ax = fig.add_axes([1,1,1,1])
ax.plot(x,y)
plt.show()

# %%
# 3rd method recommened
fig , ax = plt.subplots()
ax.plot(x,y); #add some data

# %%
fig, ax = plt.subplots(); 
ax.plot(x,[50,100,200,250]);
type(fig), type(ax)
# Out:
# (matplotlib.figure.Figure, matplotlib.axes._axes.Axes)

# %% [markdown]
# ## Matplotlib Example Workflow

# %%
#0.import matplotlib and get it ready for plotting in Jupyter
# %matplotlib inline
import matplotlib.pyplot as plt

#1. Prepare data
x=[1,2,3,4]
y=[11,22,33,44]

#2. Setup plot
fig, ax=plt.subplots(figsize=(10,10))  #width #heigth

#3. plot data
ax.plot(x,y);

#4.customize plot
ax.set(title= "Simple Plot",
      xlabel ="x-axis",
      ylabel = "y-axis")

#5. Save and show (you save the whole figure)
fig.savefig("Images created/sample-plot.png")

# %% [markdown]
# ## Making Figures with Numpy arrays
#
# We want:
# * Line plt
# * scatter plot
# * Bar Plot
# * Histogam
# * Subplots

# %%
import numpy as np

# %%
# create some data
x = np.linspace(0,10,100)
x[:10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %%
#plot the data and create a line plot
fig, ax = plt.subplots()
ax.plot(x,x**2);

# %%
#Use same data to make scatter plot
fi,ax = plt.subplots()
ax.scatter(x,np.exp(x));

# %%
# Another scatter plot
fig, ax = plt.subplots()
ax.scatter(x,np.sin(x));

# %%
# Make a plot from dictionary
nut_butter_prices = {"Almond butter": 10,
                    "Peanut Butter":8,
                    "Cashew Butter":12}

fig, ax= plt.subplots()
ax.bar(nut_butter_prices.keys(), height =nut_butter_prices.values()); #positional arguments
ax.set(title="Karthik's Nut Butter Store",
      ylabel="Prices(₹)");

# %%
fig, ax = plt.subplots()
ax.barh(list(nut_butter_prices.keys()), list(nut_butter_prices.values())); # barh 'h' is for horizontal and use arguments in lists

# %%
# Make some data for histogram
x = np.random.randn(1000) #just data cretaed for histogram and randn creates normal distribution
fig, ax = plt.subplots()
ax.hist(x);

# %% [markdown]
# ## Two options for subplots

# %%
fig, ((ax1, ax2), (ax3,ax4)) = plt.subplots(nrows=2,
                                           ncols=2,
                                           figsize=(10,5))

# %%
# Subplot option 1
fig, ((ax1, ax2), (ax3,ax4)) = plt.subplots(nrows=2,
                                           ncols=2,
                                           figsize=(10,5))

#plot to each differnt axis

ax1.plot(x,x/2);
ax2.scatter(np.random.random(10),np.random.random(10));
ax3.bar(nut_butter_prices.keys(), nut_butter_prices.values());
ax4.hist(np.random.randn(1000));

# %%
#Subplots Option 2
fig, ax = plt.subplots(nrows=2,
                        ncols=2,
                        figsize=(10,5))

# Plot to each different index
ax[0,0].plot(x,x/2);
ax[0,1].scatter(np.random.random(10), np.random.random(10));
ax[1,0].bar(nut_butter_prices.keys(), nut_butter_prices.values());
ax[1,1].hist(np.random.randn(1000));

# %% [markdown]
# ## Plotting from pandas DataFrames

# %%
import pandas as pd

# %%
# Make a dataframe
car_sales = pd.read_csv("car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
ts = pd.Series(np.random.randn(1000),
             index=pd.date_range("08/03/2024", periods=1000))
ts=ts.cumsum()

ts.plot();

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]','') #here  str.replace $ , . signs are beign replcaes with ''
car_sales
# Out:
# C:\Users\karth\AppData\Local\Temp\ipykernel_1348\1824865924.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]','') #here  str.replace $ , . signs are beign replcaes with ''
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
type(car_sales["Price"])
# Out:
# pandas.core.series.Series

# %%
#Remove last two zeros 
car_sales["Price"] = car_sales["Price"].str[:-2]

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales["Sale Date"]=pd.date_range("03/08/2024", periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date
# 0  Toyota  White         150043      4   4000 2024-03-08
# 1   Honda    Red          87899      4   5000 2024-03-09
# 2  Toyota   Blue          32549      3   7000 2024-03-10
# 3     BMW  Black          11179      5  22000 2024-03-11
# 4  Nissan  White         213095      4   3500 2024-03-12
# 5  Toyota  Green          99213      4   4500 2024-03-13
# 6   Honda   Blue          45698      4   7500 2024-03-14
# 7   Honda   Blue          54738      4   7000 2024-03-15
# 8  Toyota  White          60000      4   6250 2024-03-16
# 9  Nissan  White          31600      4   9700 2024-03-17

# %%
car_sales["Total sales"] = car_sales["Price"].astype(int).cumsum()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total sales
# 0  Toyota  White         150043      4   4000 2024-03-08         4000
# 1   Honda    Red          87899      4   5000 2024-03-09         9000
# 2  Toyota   Blue          32549      3   7000 2024-03-10        16000
# 3     BMW  Black          11179      5  22000 2024-03-11        38000
# 4  Nissan  White         213095      4   3500 2024-03-12        41500
# 5  Toyota  Green          99213      4   4500 2024-03-13        46000
# 6   Honda   Blue          45698      4   7500 2024-03-14        53500
# 7   Honda   Blue          54738      4   7000 2024-03-15        60500
# 8  Toyota  White          60000      4   6250 2024-03-16        66750
# 9  Nissan  White          31600      4   9700 2024-03-17        76450

# %%
# Lets plot the total sales
car_sales.plot(x="Sale Date", y="Total sales");

# %%
#Reassign price colomn to int
car_sales["Price"] = car_sales["Price"].astype(int)

# Plot scatter plot with price colomn as numeric
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter");

# %%
# How about a bar graph
x = np.random.rand(10,4)

# Turn it into DataFrame
df = pd.DataFrame(x, columns=(['a', 'b', 'c', 'd']))
df
# Out:
#           a         b         c         d
# 0  0.481388  0.377498  0.492655  0.423217
# 1  0.551335  0.551804  0.549433  0.796436
# 2  0.823533  0.315753  0.919898  0.404869
# 3  0.248881  0.310953  0.089808  0.527769
# 4  0.149879  0.117275  0.669324  0.997619
# 5  0.904630  0.687211  0.910034  0.240241
# 6  0.094483  0.063096  0.662793  0.143533
# 7  0.196834  0.776111  0.267374  0.621443
# 8  0.704369  0.788476  0.148846  0.560115
# 9  0.773359  0.655989  0.416613  0.674385

# %%
df.plot.bar();

# %%
df.plot(kind="bar");

# %%
car_sales.plot.bar();

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total sales
# 0  Toyota  White         150043      4   4000 2024-03-08         4000
# 1   Honda    Red          87899      4   5000 2024-03-09         9000
# 2  Toyota   Blue          32549      3   7000 2024-03-10        16000
# 3     BMW  Black          11179      5  22000 2024-03-11        38000
# 4  Nissan  White         213095      4   3500 2024-03-12        41500
# 5  Toyota  Green          99213      4   4500 2024-03-13        46000
# 6   Honda   Blue          45698      4   7500 2024-03-14        53500
# 7   Honda   Blue          54738      4   7000 2024-03-15        60500
# 8  Toyota  White          60000      4   6250 2024-03-16        66750
# 9  Nissan  White          31600      4   9700 2024-03-17        76450

# %%
car_sales.plot(x="Make", y="Odometer (KM)", kind="bar");

# %%
# Make Average of same car

# %%
# Histogram
car_sales["Odometer (KM)"].plot.hist();

# %%
car_sales["Odometer (KM)"].plot(kind="hist");

# %%
car_sales["Odometer (KM)"].plot.hist(bins=20);

# %%
# Lets ry another dataset
heart_disease = pd.read_csv("heart-disease.csv")

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_disease["age"].plot.hist(bins=10);

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_disease.plot.hist(figsize=(10,30),subplots=True);

# %% [markdown]
# ### Which one should you use? (pyplot vs matplotlib OO method?)
#
#   * When plotting something quicly, okay  to use the pyplot method
#   * When plotting something more advanced, use OO method

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
over_50 = heart_disease[heart_disease["age"]>50]
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
# Pyplot method
over_50.plot(kind="scatter",
            x="age",
            y="chol",
            c="target",
            figsize=(10,6));

# %%
# OO Method mixed with Pyplot method
fix, ax = plt.subplots(figsize=(10,6))
over_50.plot(kind='scatter',
            x='age',
            y='chol',
             c='target',
            ax=ax);

#ax.set_xlim([45,100]); # it changes the limitation to 45, 100 insted of what it is

# %%
## OO method from scratch
fig, ax = plt.subplots(figsize = (10,6))

# Plot the data 
scatter = ax.scatter(x=over_50["age"],
                    y = over_50["chol"],
                    c=over_50["target"]);

# Customize the plot
ax.set(title = "Heart Disease and Cholestrol Levels",
      xlabel = "Age",
      ylabel = "Cholestrol");

# Add a legend
ax.legend(*scatter.legend_elements(), title= "Target");

# Add a horixzontal line
ax.axhline(over_50["chol"].mean(),
          linestyle="--");

# %%
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
# Subplots of age, chol, and thalach
fig, (ax0, ax1)=plt.subplots(nrows=2,
                          ncols=1,
                          figsize=(10,10),
                            sharex=True);

# Add data to ax0
scatter = ax0.scatter(x=over_50["age"],
                     y=over_50["chol"],
                     c = over_50["target"],);

# Customize ax0
ax0.set(title="Heart Disease and Cholestrol Levels",
      ylabel="Cholestrol");

#Add a legend to ax0
ax0.legend(*scatter.legend_elements(),title="Target");

#Add a meanline to ax0
ax0.axhline(over_50["chol"].mean(),
           linestyle="--");

# Add data to ax1
scatter = ax1.scatter(x=over_50["age"],
                     y=over_50["thalach"],
                     c = over_50["target"]);

# Customize ax1
ax1.set(title="Heart Disease and Thalach Levels",
        xlabel="Age",
      ylabel="Max Heart Rate"); #Thalach means Max Heart Rate

#Add a legend to ax1
ax1.legend(*scatter.legend_elements(),title="Target");

#Add a meanline to ax1
ax1.axhline(over_50["thalach"].mean(),
           linestyle="--");

# Add a title to entire fig
fig.suptitle("Heart Disease Analsys" ,fontsize=16, fontweight="bold");

# %% [markdown]
# ## Customizing Matplotlib plot and getting stylish

# %%
# See the different style available
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use("seaborn-v0_8")

# %%
car_sales["Price"].plot();

# %%
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter");

# %%
plt.style.use('ggplot')

# %%
car_sales["Price"].plot();

# %%
x = np.random.rand(10,4)
x
# Out:
# array([[0.15933047, 0.23618534, 0.26451143, 0.43564679],
#        [0.36346883, 0.30446211, 0.70736712, 0.16267818],
#        [0.69767417, 0.22978453, 0.45815773, 0.22799174],
#        [0.91149647, 0.27398563, 0.81803887, 0.29871893],
#        [0.71545144, 0.88202613, 0.47031925, 0.19339223],
#        [0.05950308, 0.62244166, 0.50369797, 0.09692633],
#        [0.03045405, 0.7769467 , 0.14176483, 0.9670797 ],
#        [0.38673956, 0.5857754 , 0.42128336, 0.3402263 ],
#        [0.33051629, 0.73608636, 0.72260668, 0.11155168],
#        [0.16328795, 0.15597448, 0.49799018, 0.01330323]])

# %%
df = pd.DataFrame(x, columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  0.159330  0.236185  0.264511  0.435647
# 1  0.363469  0.304462  0.707367  0.162678
# 2  0.697674  0.229785  0.458158  0.227992
# 3  0.911496  0.273986  0.818039  0.298719
# 4  0.715451  0.882026  0.470319  0.193392
# 5  0.059503  0.622442  0.503698  0.096926
# 6  0.030454  0.776947  0.141765  0.967080
# 7  0.386740  0.585775  0.421283  0.340226
# 8  0.330516  0.736086  0.722607  0.111552
# 9  0.163288  0.155974  0.497990  0.013303

# %%
ax = df.plot(kind='bar');
type(ax)
# Out:
# matplotlib.axes._axes.Axes

# %%
# Customize our plot with set() method
ax = df.plot(kind="bar")

# Add some labels and title
ax.set(title="Random Number Bar Graph from DataFrame",
      xlabel="Row Numbers",
      ylabel="Random Numbers");

# Add legend 
ax.legend().set_visible(True)

# %%
# Add Style
plt.style.use('seaborn-v0_8-whitegrid')
## OO method from scratch
fig, ax = plt.subplots(figsize = (10,6))

# Plot the data 
scatter = ax.scatter(x=over_50["age"],
                    y = over_50["chol"],
                    c=over_50["target"],
                    cmap='winter'); #this changes the color scheme of dots in graph

# Customize the plot
ax.set(title = "Heart Disease and Cholestrol Levels",
      xlabel = "Age",
      ylabel = "Cholestrol");

# Add a legend
ax.legend(*scatter.legend_elements(), title= "Target");

# Add a horixzontal line
ax.axhline(over_50["chol"].mean(),
          linestyle="--");

# %%
# Customizing y and x label limitations

# Subplots of age, chol, and thalach
fig, (ax0, ax1)=plt.subplots(nrows=2,
                          ncols=1,
                          figsize=(10,10),
                            sharex=True);

# Add data to ax0
scatter = ax0.scatter(x=over_50["age"],
                     y=over_50["chol"],
                     c = over_50["target"],
                     cmap = "winter");

# Customize ax0
ax0.set(title="Heart Disease and Cholestrol Levels",
      ylabel="Cholestrol");

#changes the x axis limit
ax0.set_xlim([50,80]);

#Add a legend to ax0
ax0.legend(*scatter.legend_elements(),title="Target");

#Add a meanline to ax0
ax0.axhline(over_50["chol"].mean(),
           linestyle="--");

# Add data to ax1
scatter = ax1.scatter(x=over_50["age"],
                     y=over_50["thalach"],
                     c = over_50["target"],
                     cmap="winter");

# Customize ax1
ax1.set(title="Heart Disease and Thalach Levels",
        xlabel="Age",
      ylabel="Max Heart Rate"); #Thalach means Max Heart Rate
# Change ax1 x axis limit
ax1.set_xlim([50,80])
ax1.set_ylim([60,200])

#Add a legend to ax1
ax1.legend(*scatter.legend_elements(),title="Target");

#Add a meanline to ax1
ax1.axhline(over_50["thalach"].mean(),
           linestyle="--");

# Add a title to entire fig
fig.suptitle("Heart Disease Analsys" ,fontsize=16, fontweight="bold");

# %%
fig.savefig("Heart-disease-analsys-saved-with-code.png")
